# %%
from src.random_hamiltonian import random_unitary
import matplotlib.pyplot as plt
import numpy as np
from src import measurements as measure, density_matrix as DM
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# /var/folders/x8/hv6lnsx5209d4m84b842j095n23ctf/T/ipykernel_99317/1655978016.py in <module>
# ----> 1 from src.random_hamiltonian import random_unitary
#       2 import matplotlib.pyplot as plt
#       3 import numpy as np
#       4 from src import measurements as measure, density_matrix as DM
#
# ModuleNotFoundError: No module named 'src'

# %%
sys = DM.n_thermal_qbits([.1,.1,.1,.1])
sys.change_to_energy_basis()
sys.plot()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /var/folders/x8/hv6lnsx5209d4m84b842j095n23ctf/T/ipykernel_99317/3570730571.py in <module>
# ----> 1 sys = DM.n_thermal_qbits([.1,.1,.1,.1])
#       2 sys.change_to_energy_basis()
#       3 sys.plot()
#
# NameError: name 'DM' is not defined

# %%
for i in range(100):
    U = random_unitary(4)
    sys = U * sys * U.H
sys.plot()

# %%
sys = DM.n_thermal_qbits([.1,.2,.1,.1])
sys.change_to_energy_basis()
sys.plot()
for i in range(100):
    U = random_unitary(4)
    sys = U * sys * U.H
sys.plot()
