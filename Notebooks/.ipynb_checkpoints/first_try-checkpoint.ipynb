# %%
# Add directory above current directory to path
import sys; sys.path.insert(0, '..')

# %%
import numpy as np
import scipy as sp
import matplotlib as plt
from src.density_matrix import n_thermal_qbits

# %%
in_energy_basis = n_thermal_qbits([0.2,0.2,0.2,0.2])
in_energy_basis.change_to_energy_basis()
in_energy_basis.plot()
