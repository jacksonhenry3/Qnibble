# %%
from src.random_hamiltonian import random_unitary,random_unitary_in_subspace

# %%
random_unitary(4).plot()

# %% [markdown]
# At the moment it works completly differently (by calculating a hamiltonian), but we can also generate random unitaries that only act in a specified energy subspace.

# %%
random_unitary_in_subspace(4,1).plot()
